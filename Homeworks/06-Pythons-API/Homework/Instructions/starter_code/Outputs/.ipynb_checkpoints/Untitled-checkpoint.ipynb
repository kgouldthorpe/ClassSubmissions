# %%
import pandas as pd

# %%
cities = "cities.csv"

# %%
cities_df = pd.read_csv(cities)
cities_df.head()
# Out:
#         City  City ID  Location  Temperature  Humidity  Cloudiness  Wind Speed
# 0    Ushuaia     8303    -54.81       272.15        80          75       11.30
# 1    Margate     9545    -43.03       281.48        61          75        4.60
# 2  Cape Town     1899    -33.93       286.15        87           0        5.10
# 3     Albany     3273     42.65       299.82        88          75        3.60
# 4  Tuatapere  2008959    -46.13       280.93        79          93        2.24

# %%
print(cities_df.to_html())
# Out:
# <bound method DataFrame.to_html of                           City  City ID  Location  Temperature  Humidity  \
# 0                      Ushuaia     8303    -54.81       272.15        80
# 1                      Margate     9545    -43.03       281.48        61
# 2                    Cape Town     1899    -33.93       286.15        87
# 3                       Albany     3273     42.65       299.82        88
# 4                    Tuatapere  2008959    -46.13       280.93        79
# 5                  Port Alfred  2011314    -33.59       289.26        67
# 6                 Punta Arenas     8487    -53.16       273.15        60
# 7                      Mataura  2008959    -46.19       280.93        79
# 8                   Georgetown     8776      6.80       303.15        66
# 9              Arraial do Cabo     8326    -22.97       294.15        88
# 10                   Mount Isa     9495    -20.73       283.15        43
# ...
