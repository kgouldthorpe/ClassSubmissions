# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Outputs/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1f623a131b12> in <module>
#      10
#      11 # Incorporated citipy to determine city based on latitude and longitude
# ---> 12 from citipy import citipy
#      13
#      14 # Output File (CSV)
#
# ModuleNotFoundError: No module named 'citipy'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
       
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define base url for API call
base_url = "http://api.openweathermap.org/data/2.5/weather?"

#Identify lists for dataframe
names = []
identification = []
lats = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []

#Create for loop to run through each city
for city in cities:
    query_url = base_url + "appid=" + api_key + "&q=" + city
    response = requests.get(query_url)
    weather_json = response.json()
    
    #Append each list for dataframe, making sure to have an out for errors
    try:
        if weather_json["sys"]["id"] > 0:
            loc = weather_json["name"]
            names.append(loc)
        ids = weather_json["sys"]["id"]
        identification.append(ids)
        lat = weather_json["coord"]["lat"]
        lats.append(lat)
        temp = weather_json["main"]["temp_max"]
        temperature.append(temp)
        humid = weather_json["main"]["humidity"]
        humidity.append(humid)
        cloud = weather_json["clouds"]["all"]
        cloudiness.append(cloud)
        wind = weather_json["wind"]["speed"]
        wind_speed.append(wind)
        
        print(f"Processing Data for {ids}: {loc}")
        
    except KeyError:
        print("No data available - moving to next city.")
# Out:
# Processing Data for 8303: Ushuaia
# Processing Data for 9545: Margate
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1899: Cape Town
# No data available - moving to next city.
# Processing Data for 3273: Albany
# Processing Data for 2008959: Tuatapere
# Processing Data for 2011314: Port Alfred
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8487: Punta Arenas
# Processing Data for 2008959: Mataura
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8776: Georgetown
# No data available - moving to next city.
# Processing Data for 8326: Arraial do Cabo
# Processing Data for 9495: Mount Isa
# Processing Data for 5145: Orange Cove
# Processing Data for 6874: Wanning
# Processing Data for 81: Tasiilaq
# No data available - moving to next city.
# Processing Data for 776: Clyde River
# No data available - moving to next city.
# Processing Data for 9030: Spornoye
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 819: Hay River
# Processing Data for 8038: Katsuura
# Processing Data for 1596: Klaksvik
# Processing Data for 2003650: Hermanus
# No data available - moving to next city.
# Processing Data for 75281: Dunedin
# Processing Data for 9545: Hobart
# Processing Data for 942: Tuktoyaktuk
# Processing Data for 8926: Nikolskoye
# No data available - moving to next city.
# Processing Data for 1435: Inverness
# Processing Data for 6734: Vila
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 4980: Pacific Grove
# Processing Data for 7263: Dangriga
# Processing Data for 7879: Kahului
# No data available - moving to next city.
# Processing Data for 9372: Victoria
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1352: Kuusamo
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7151: Cabo San Lucas
# Processing Data for 2061: Mahebourg
# Processing Data for 8691: Pisco
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7754: Ketchikan
# Processing Data for 1681: Tromso
# Processing Data for 6708: Santa Rosalia
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7881: Hilo
# No data available - moving to next city.
# Processing Data for 2453: Lebu
# Processing Data for 7873: Kapaa
# Processing Data for 1343: Kokkola
# No data available - moving to next city.
# Processing Data for 7318: Tautira
# Processing Data for 7217: Miramar
# Processing Data for 2000217: Kaitangata
# Processing Data for 7271: Avarua
# No data available - moving to next city.
# Processing Data for 1663: Longyearbyen
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1467: Broome
# No data available - moving to next city.
# Processing Data for 935: Thompson
# Processing Data for 8521: Puerto Ayora
# Processing Data for 818: Hamilton
# Processing Data for 986: Fort Nelson
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2019717: Necochea
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9725: Belen
# No data available - moving to next city.
# Processing Data for 90: Grindavik
# Processing Data for 1616: Raudeberg
# Processing Data for 2021131: Sitka
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1838: Schweinfurt
# Processing Data for 2517: Marsa Matruh
# No data available - moving to next city.
# Processing Data for 2011706: Busselton
# Processing Data for 762: Shelburne
# Processing Data for 8491: Coihaique
# Processing Data for 1013: Sept-Iles
# No data available - moving to next city.
# Processing Data for 9021: Stolbovaya
# Processing Data for 998: Torbay
# Processing Data for 7113: Constitucion
# Processing Data for 7292: Neiafu
# No data available - moving to next city.
# Processing Data for 7562: Salalah
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7103: Tecoanapa
# No data available - moving to next city.
# Processing Data for 7432: Turayf
# Processing Data for 8480: Calama
# No data available - moving to next city.
# Processing Data for 4042: Kodiak
# Processing Data for 951: Norman Wells
# No data available - moving to next city.
# Processing Data for 4902: Port Elizabeth
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1007: Yellowknife
# Processing Data for 8810: El Dorado
# Processing Data for 5898: Spearfish
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7306: Alofi
# Processing Data for 7162: Champerico
# Processing Data for 2061: Quatre Cocos
# Processing Data for 2020551: Pemberton
# No data available - moving to next city.
# Processing Data for 8074: Nishihara
# Processing Data for 2011706: Collie
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2010964: Waipawa
# Processing Data for 8901: Krynychky
# No data available - moving to next city.
# Processing Data for 9594: Kiama
# No data available - moving to next city.
# Processing Data for 9440: Kuala Terengganu
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 6892: Lagoa
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 3618: Soddy-Daisy
# Processing Data for 3343: Watertown
# Processing Data for 2061: Bambous Virieux
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2008803: Goderich
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7955: Hasaki
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1503: Skegness
# Processing Data for 6452: Souillac
# No data available - moving to next city.
# Processing Data for 2001912: Kristinehamn
# Processing Data for 9683: Morro Bay
# No data available - moving to next city.
# Processing Data for 2059: Komatipoort
# Processing Data for 8512: Ancud
# No data available - moving to next city.
# Processing Data for 8784: Dennery
# No data available - moving to next city.
# Processing Data for 19218: Husavik
# No data available - moving to next city.
# Processing Data for 8648: El Alto
# No data available - moving to next city.
# Processing Data for 906: Thunder Bay
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2012545: Henties Bay
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 6374: Lasa
# No data available - moving to next city.
# Processing Data for 858: Mayo
# Processing Data for 4784: Carbondale
# Processing Data for 2173: Luanda
# Processing Data for 7317: Isangel
# Processing Data for 3437: Beatrice
# Processing Data for 9333: Denpasar
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 940: Iroquois Falls
# Processing Data for 6945: Oga
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9605: Nelson Bay
# Processing Data for 7840: Bethel
# Processing Data for 8360: Imbituba
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8479: Collipulli
# Processing Data for 9687: Esna
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9483: Alice Springs
# Processing Data for 1366: Heinola
# No data available - moving to next city.
# Processing Data for 8021: Susaki
# Processing Data for 2061: Cap Malheureux
# Processing Data for 3408: Winfield
# No data available - moving to next city.
# Processing Data for 794: Mackay
# Processing Data for 8020: Tateyama
# Processing Data for 6391: Fortuna
# Processing Data for 7458: Mehran
# Processing Data for 5100: Livingston
# Processing Data for 3785: Edgewater
# No data available - moving to next city.
# Processing Data for 1966: Bredasdorp
# Processing Data for 7684: Fairbanks
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2271: Sesheke
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9609: Mentougou
# Processing Data for 9545: New Norfolk
# Processing Data for 86: Nuuk
# Processing Data for 983: Whitehorse
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9124: Haputale
# Processing Data for 797: Iqaluit
# Processing Data for 8452: Touros
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8335: Puerto Quijarro
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9124: Hambantota
# No data available - moving to next city.
# Processing Data for 165: Ilulissat
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8694: Iquitos
# Processing Data for 7421: Najran
# Processing Data for 3938: Bellefontaine
# Processing Data for 4747: Lompoc
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 968: Pangnirtung
# Processing Data for 6899: Ponta Delgada
# Processing Data for 47: Qaqortoq
# No data available - moving to next city.
# Processing Data for 8512: Castro
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 3409: Westport
# Processing Data for 8001: Kushima
# No data available - moving to next city.
# Processing Data for 8440: Morros
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9487: Yulara
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8942: Belyy Yar
# Processing Data for 2271: Katima Mulilo
# Processing Data for 5903: Half Moon Bay
# No data available - moving to next city.
# Processing Data for 1601: Mettlach
# Processing Data for 1271: Soller
# Processing Data for 3814: Saint Anthony
# No data available - moving to next city.
# Processing Data for 3217: Eureka
# Processing Data for 8890: Novokruchininskiy
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 6576: Ambon
# No data available - moving to next city.
# Processing Data for 4146: Saint-Philippe
# No data available - moving to next city.
# Processing Data for 2007154: Marawi
# Processing Data for 9560: Mount Gambier
# No data available - moving to next city.
# Processing Data for 7286: Pangai
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 4360: Vardo
# Processing Data for 8334: Niteroi
# No data available - moving to next city.
# Processing Data for 949: La Ronge
# Processing Data for 7260: High Rock
# Processing Data for 1633: Berlevag
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8454: Camacari
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 4874: Nuevo Progreso
# No data available - moving to next city.
# Processing Data for 7576: Karachi
# Processing Data for 3787: Washington DC.
# No data available - moving to next city.
# Processing Data for 859: Chapais
# No data available - moving to next city.
# Processing Data for 2007247: Mildura
# No data available - moving to next city.
# Processing Data for 8408: Rio Grande
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9215: Port Blair
# Processing Data for 2017542: Koutsouras
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 4695: Portland
# No data available - moving to next city.
# Processing Data for 7156: Ixtapa
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9612: Zhuhai
# No data available - moving to next city.
# Processing Data for 9525: Esperance
# Processing Data for 2757: Glendive
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8363: Vila Velha
# No data available - moving to next city.
# Processing Data for 8875: Provideniya
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8712: Maldonado
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8514: Coquimbo
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2188: Port-Gentil
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8462: Rio Claro
# No data available - moving to next city.
# Processing Data for 1013: Port-Cartier
# No data available - moving to next city.
# Processing Data for 7729: Juneau
# Processing Data for 821: Aklavik
# Processing Data for 2006944: Dalvik
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7166: Manzanillo
# Processing Data for 3726: Rapid City
# Processing Data for 6895: Praia da Vitoria
# Processing Data for 8284: Comodoro Rivadavia
# Processing Data for 9490: Mareeba
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7008: Erzin
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 3428: Tullahoma
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1602: Roald
# Processing Data for 1676: Hovd
# Processing Data for 9589: Katherine
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 3276: Walla Walla
# Processing Data for 4696: Frankfort
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1098: Adrar
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7157: Puerto Escondido
# No data available - moving to next city.
# Processing Data for 8986: Strezhevoy
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7105: Morant Bay
# No data available - moving to next city.
# Processing Data for 9594: Flinders
# No data available - moving to next city.
# Processing Data for 6736: Aosta
# No data available - moving to next city.
# Processing Data for 8492: Iquique
# Processing Data for 9537: Codrington
# Processing Data for 6720: Capoterra
# Processing Data for 922: Revelstoke
# Processing Data for 4869: Medford
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1702: Ryki
# Processing Data for 9071: Dumas
# No data available - moving to next city.
# Processing Data for 6403: Bereda
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9594: Ulladulla
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2011693: Nybro
# Processing Data for 6902: Camacha
# No data available - moving to next city.
# Processing Data for 1438: Brae
# Processing Data for 2002961: Whitianga
# Processing Data for 782: Flin Flon
# Processing Data for 6996: Durusu
# Processing Data for 7210: Nicoya
# No data available - moving to next city.
# Processing Data for 9508: Townsville
# Processing Data for 4529: Pahrump
# No data available - moving to next city.
# Processing Data for 8337: Sao Joao da Barra
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7121: Tenabo
# Processing Data for 8792: Loiza
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 6533: Fecamp
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1366: Tornio
# Processing Data for 83: Akureyri
# Processing Data for 9366: Kuching
# Processing Data for 2061: Grand Baie
# No data available - moving to next city.
# Processing Data for 1563: Skibbereen
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8293: Rio Gallegos
# No data available - moving to next city.
# Processing Data for 6535: Saint-Pierre
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 1008: Slave Lake
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8971: Almaznyy
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 756: Nipawin
# No data available - moving to next city.
# Processing Data for 6087: Tooele
# No data available - moving to next city.
# Processing Data for 8520: Llaillay
# No data available - moving to next city.
# Processing Data for 3706: Corsicana
# No data available - moving to next city.
# Processing Data for 833: Meadow Lake
# Processing Data for 6507: Saint-Joseph
# Processing Data for 2202: Maputo
# Processing Data for 1415: Blackwater
# Processing Data for 8138: Gushikawa
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 4714: Limon
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8772: Bathsheba
# No data available - moving to next city.
# Processing Data for 1646: Karasjok
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 8972: Sochi
# No data available - moving to next city.
# Processing Data for 7613: Safita
# Processing Data for 8799: Road Town
# Processing Data for 9208: Nandi
# No data available - moving to next city.
# Processing Data for 3951: Crestview
# Processing Data for 5194: Galveston
# No data available - moving to next city.
# Processing Data for 6562: Plerin
# Processing Data for 2016422: Kaeo
# Processing Data for 6403: Carballo
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9548: Olinda
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7587: Sakrand
# No data available - moving to next city.
# Processing Data for 2011346: Venado Tuerto
# Processing Data for 7537: Dubai
# Processing Data for 1533: Den Helder
# No data available - moving to next city.
# Processing Data for 2013233: Bajil
# Processing Data for 8137: Itoman
# Processing Data for 7424: Riyadh
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 2012217: Ngunguru
# Processing Data for 6455: Moissac
# Processing Data for 8898: Semypolky
# Processing Data for 4558: Isla Vista
# No data available - moving to next city.
# Processing Data for 990: Smithers
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 9308: Hoa Binh
# Processing Data for 1399: Warrington
# Processing Data for 8887: Petropavlovsk-Kamchatskiy
# Processing Data for 5443: Plainview
# Processing Data for 7411: Buraydah
# No data available - moving to next city.
# Processing Data for 6720: Carbonia
# No data available - moving to next city.
# Processing Data for 5990: Fredericksburg
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 5228: Evanston
# Processing Data for 8669: Cayenne
# No data available - moving to next city.
# No data available - moving to next city.
# Processing Data for 7103: Acapulco
# No data available - moving to next city.
# Processing Data for 870: Elk Point

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create output file location for graphs
output = "C:\\Users\\kenda\\OneDrive\\Documents\\GitHub\\ClassSubmissions\\Homeworks\\06-Pythons-API\\Homework\\Instructions\\starter_code\\Outputs\\"

#Create dataframe
data = {"City": names, "City ID": identification, "Location": lats, "Temperature": temperature, "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed": wind_speed}
data_df = pd.DataFrame(data)
data_df

#Convert DF to CSV and save file
data_df.to_csv(output_data_file, index = False)

#View df
data_df.head(10)
# Out:
#               City  City ID  Location  Temperature  Humidity  Cloudiness  \
# 0          Ushuaia     8303    -54.81       272.15        80          75
# 1          Margate     9545    -43.03       281.48        61          75
# 2        Cape Town     1899    -33.93       286.15        87           0
# 3           Albany     3273     42.65       299.82        88          75
# 4        Tuatapere  2008959    -46.13       280.93        79          93
# 5      Port Alfred  2011314    -33.59       289.26        67           0
# 6     Punta Arenas     8487    -53.16       273.15        60          75
# 7          Mataura  2008959    -46.19       280.93        79          88
# 8       Georgetown     8776      6.80       303.15        66          40
# 9  Arraial do Cabo     8326    -22.97       294.15        88          75
#
#    Wind Speed
# 0       11.30
# 1        4.60
# 2        5.10
# 3        3.60
# 4        2.24
# 5        3.13
# 6       12.90
# 7        2.24
# 8        2.10
# 9        5.10

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
latvtemp = data_df.plot.scatter(x = 'Location', y = 'Temperature', c='DarkBlue', title ="Temperature vs Location", grid = True)

latvtemp.get_figure().savefig(output+"latvtemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
latvhum = data_df.plot.scatter(x = 'Location', y = 'Humidity', c='DarkGreen', title ="Humidity vs Location", grid = True, ylim = [0,120])

latvhum.get_figure().savefig(output+"latvhum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
latvcloud = data_df.plot.scatter(x = 'Location', y = 'Cloudiness', c='Orange', title ="Cloudiness vs Location", grid = True)

latvcloud.get_figure().savefig(output+"latvcloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
latvwind = data_df.plot.scatter(x = 'Location', y = 'Wind Speed', c='Purple', title ="Wind Speed vs Location", grid = True)

latvwind.get_figure().savefig(output+"latvwind.png")

# %%
#OBSERVATIONS:
#1 - The data proves that there tends to be a higher temperature the closer you get to the equator.
#2 - Cities seem to be cloudier north of the equator.
#3 - Humidity becomes a greater issue as you come away from the equator.
